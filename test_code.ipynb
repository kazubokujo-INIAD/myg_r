# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# データの読み込み
TDS_7=pd.read_csv('data/TDS_7.csv',header=0)
TDS_8=pd.read_csv('data/TDS_8.csv',header=0)
data=pd.concat([TDS_7, TDS_8], ignore_index=True)
data = data.drop(columns=['Unnamed: 0'])



# 各アトラクションの所要時間と人気度を設定
attractions = ['ソアリン', 'トイストーリーマニア', 'タワーオブテラー', 'センターオブジアース', 'インディージョーンズ', 'レイジングスピリッツ', 'マジックランプシアター', 'タートルトーク']
required_times = [5, 7, 2, 3, 3, 2, 23, 30]
popularity = [84, 69, 55, 45, 33, 28, 19, 22]

data.head()
data.tail()
# Out:
#                        時間  ソアリン  トイストーリーマニア  タワーオブテラー  センターオブジアース  インディージョーンズ  \
# 5659  2023-08-30 19:45:00    70          45        50          30          55
# 5660  2023-08-30 20:00:00    65          55        40          30          30
# 5661  2023-08-30 20:15:00    60          35        30          30          20
# 5662  2023-08-30 20:30:00    55          30        30          20          25
# 5663  2023-08-30 20:45:00     0           0         0           0           0
#
#       レイジングスピリッツ  マジックランプシアター  タートルトーク  曜日_数値         曜日     休日
# 5659          20           15       20      2  Wednesday  False
# 5660          20           20       15      2  Wednesday  False
# 5661          15           25       15      2  Wednesday  False
# 5662          15           25       20      2  Wednesday  False
# 5663          20            0       15      2  Wednesday  False

# %%
import os
import pandas as pd
from datetime import datetime, timedelta

# ナップザック問題を解く関数
def knapsack(max_time, required_times, popularity, waiting_times, move_time):
    n = len(required_times)
    dp = [0] * (max_time + 1)
    keep = [False] * (max_time + 1)

    for i in range(n):
        for w in range(max_time, required_times[i] - 1, -1):
            if dp[w - required_times[i]] + popularity[i] > dp[w]:
                dp[w] = dp[w - required_times[i]] + popularity[i]
                keep[w] = True

    # 解を復元する
    res = []
    w = max_time
    for i in range(n - 1, -1, -1):
        if keep[w]:
            res.append(attractions[i])
            w -= required_times[i]

    res.reverse()
    return res, dp[max_time]

# date_dataフォルダ内のファイルを処理する
folder_path = 'date_data'
results = {}

for folder_name in os.listdir(folder_path):
    folder_dir = os.path.join(folder_path, folder_name)
    if os.path.isdir(folder_dir):
        data = pd.read_csv(os.path.join(folder_dir, 'data.csv'))  # ファイルの読み込み

        max_time = 705  # パーク内にいる時間 9:00~20:45 計705分
        move_time = 30  # アトラクション間の移動時間 30分
        start_time = datetime.strptime('2022-07-01 09:00:00', '%Y-%m-%d %H:%M:%S')

        best_plan = []
        max_popularity = 0

        for index, row in data.iterrows():
            waiting_times = row.tolist()[1:]  # アトラクションごとの待ち時間
            plan, popularity_score = knapsack(max_time, required_times, popularity, waiting_times, move_time)
            if popularity_score > max_popularity:
                max_popularity = popularity_score
                best_plan = plan

        results[folder_name] = (best_plan, max_popularity)

# 結果を表示
for folder_name, (best_plan, max_popularity) in results.items():
    print(f"フォルダ名: {folder_name}")
    print("最適なアトラクションスケジュール:")
    for attraction in best_plan:
        print(f"- {attraction}")
    print("最大人気度スコア:", max_popularity)
    print("-" * 40)
# Out:
# Batch 1 のスケジュールと最大人気度スコア:
# 2022-07-01 09:32:00 に タワーオブテラー に乗ります
# 2022-07-01 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-01 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 2 のスケジュールと最大人気度スコア:
# 2022-07-02 09:32:00 に タワーオブテラー に乗ります
# 2022-07-02 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-02 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 3 のスケジュールと最大人気度スコア:
# 2022-07-03 09:32:00 に タワーオブテラー に乗ります
# 2022-07-03 10:19:00 に トイストーリーマニア に乗ります
# 2022-07-03 10:24:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 4 のスケジュールと最大人気度スコア:
# 2022-07-04 10:02:00 に トイストーリーマニア に乗ります
# 2022-07-04 10:37:00 に ソアリン に乗ります
# 最大人気度スコア: 153.0
# ----------------------------------------
# Batch 5 のスケジュールと最大人気度スコア:
# 2022-07-05 09:32:00 に タワーオブテラー に乗ります
# 2022-07-05 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-05 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 6 のスケジュールと最大人気度スコア:
# 2022-07-06 09:32:00 に タワーオブテラー に乗ります
# 2022-07-06 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-06 10:39:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 7 のスケジュールと最大人気度スコア:
# 2022-07-07 09:32:00 に タワーオブテラー に乗ります
# 2022-07-07 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-07 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 8 のスケジュールと最大人気度スコア:
# 2022-07-08 09:32:00 に タワーオブテラー に乗ります
# 2022-07-08 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-08 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 9 のスケジュールと最大人気度スコア:
# 2022-07-09 09:32:00 に タワーオブテラー に乗ります
# 2022-07-09 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-09 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 10 のスケジュールと最大人気度スコア:
# 2022-07-10 09:32:00 に タワーオブテラー に乗ります
# 2022-07-10 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-10 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 11 のスケジュールと最大人気度スコア:
# 2022-07-11 09:32:00 に タワーオブテラー に乗ります
# 2022-07-11 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-11 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 12 のスケジュールと最大人気度スコア:
# 2022-07-12 09:32:00 に タワーオブテラー に乗ります
# 2022-07-12 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-12 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 13 のスケジュールと最大人気度スコア:
# 2022-07-13 09:32:00 に タワーオブテラー に乗ります
# 2022-07-13 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-13 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 14 のスケジュールと最大人気度スコア:
# 2022-07-14 09:37:00 に トイストーリーマニア に乗ります
# 2022-07-14 10:12:00 に ソアリン に乗ります
# 最大人気度スコア: 153.0
# ----------------------------------------
# Batch 15 のスケジュールと最大人気度スコア:
# 2022-07-15 09:32:00 に タワーオブテラー に乗ります
# 2022-07-15 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-15 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 16 のスケジュールと最大人気度スコア:
# 2022-07-16 09:32:00 に タワーオブテラー に乗ります
# 2022-07-16 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-16 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 17 のスケジュールと最大人気度スコア:
# 2022-07-17 09:32:00 に タワーオブテラー に乗ります
# 2022-07-17 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-17 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 18 のスケジュールと最大人気度スコア:
# 2022-07-18 09:32:00 に タワーオブテラー に乗ります
# 2022-07-18 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-18 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 19 のスケジュールと最大人気度スコア:
# 2022-07-19 09:32:00 に タワーオブテラー に乗ります
# 2022-07-19 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-19 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 20 のスケジュールと最大人気度スコア:
# 2022-07-20 09:32:00 に タワーオブテラー に乗ります
# 2022-07-20 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-20 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 21 のスケジュールと最大人気度スコア:
# 2022-07-21 09:32:00 に タワーオブテラー に乗ります
# 2022-07-21 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-21 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 22 のスケジュールと最大人気度スコア:
# 2022-07-22 09:32:00 に タワーオブテラー に乗ります
# 2022-07-22 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-22 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 23 のスケジュールと最大人気度スコア:
# 2022-07-23 09:32:00 に タワーオブテラー に乗ります
# 2022-07-23 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-23 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 24 のスケジュールと最大人気度スコア:
# 2022-07-24 09:32:00 に タワーオブテラー に乗ります
# 2022-07-24 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-24 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 25 のスケジュールと最大人気度スコア:
# 2022-07-25 09:32:00 に タワーオブテラー に乗ります
# 2022-07-25 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-25 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 26 のスケジュールと最大人気度スコア:
# 2022-07-26 09:32:00 に タワーオブテラー に乗ります
# 2022-07-26 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-26 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 27 のスケジュールと最大人気度スコア:
# 2022-07-27 09:32:00 に タワーオブテラー に乗ります
# 2022-07-27 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-27 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 28 のスケジュールと最大人気度スコア:
# 2022-07-28 09:32:00 に タワーオブテラー に乗ります
# 2022-07-28 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-28 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 29 のスケジュールと最大人気度スコア:
# 2022-07-29 09:32:00 に タワーオブテラー に乗ります
# 2022-07-29 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-29 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 30 のスケジュールと最大人気度スコア:
# 2022-07-30 09:32:00 に タワーオブテラー に乗ります
# 2022-07-30 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-30 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 31 のスケジュールと最大人気度スコア:
# 2022-07-31 09:32:00 に タワーオブテラー に乗ります
# 2022-07-31 10:09:00 に トイストーリーマニア に乗ります
# 2022-07-31 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 32 のスケジュールと最大人気度スコア:
# 2022-08-01 09:32:00 に タワーオブテラー に乗ります
# 2022-08-01 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-01 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 33 のスケジュールと最大人気度スコア:
# 2022-08-02 09:32:00 に タワーオブテラー に乗ります
# 2022-08-02 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-02 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 34 のスケジュールと最大人気度スコア:
# 2022-08-03 09:32:00 に タワーオブテラー に乗ります
# 2022-08-03 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-03 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 35 のスケジュールと最大人気度スコア:
# 2022-08-04 09:32:00 に タワーオブテラー に乗ります
# 2022-08-04 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-04 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 36 のスケジュールと最大人気度スコア:
# 2022-08-05 09:32:00 に タワーオブテラー に乗ります
# 2022-08-05 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-05 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 37 のスケジュールと最大人気度スコア:
# 2022-08-06 09:32:00 に タワーオブテラー に乗ります
# 2022-08-06 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-06 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 38 のスケジュールと最大人気度スコア:
# 2022-08-07 09:32:00 に タワーオブテラー に乗ります
# 2022-08-07 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-07 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 39 のスケジュールと最大人気度スコア:
# 2022-08-08 09:32:00 に タワーオブテラー に乗ります
# 2022-08-08 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-08 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 40 のスケジュールと最大人気度スコア:
# 2022-08-09 09:32:00 に タワーオブテラー に乗ります
# 2022-08-09 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-09 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 41 のスケジュールと最大人気度スコア:
# 2022-08-10 09:32:00 に タワーオブテラー に乗ります
# 2022-08-10 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-10 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 42 のスケジュールと最大人気度スコア:
# 2022-08-11 09:32:00 に タワーオブテラー に乗ります
# 2022-08-11 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-11 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 43 のスケジュールと最大人気度スコア:
# 2022-08-12 09:32:00 に タワーオブテラー に乗ります
# 2022-08-12 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-12 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 44 のスケジュールと最大人気度スコア:
# 2022-08-13 09:32:00 に タワーオブテラー に乗ります
# 2022-08-13 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-13 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 45 のスケジュールと最大人気度スコア:
# 2022-08-14 09:32:00 に タワーオブテラー に乗ります
# 2022-08-14 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-14 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 46 のスケジュールと最大人気度スコア:
# 2022-08-15 09:32:00 に タワーオブテラー に乗ります
# 2022-08-15 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-15 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 47 のスケジュールと最大人気度スコア:
# 2022-08-16 09:32:00 に タワーオブテラー に乗ります
# 2022-08-16 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-16 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 48 のスケジュールと最大人気度スコア:
# 2022-08-17 09:32:00 に タワーオブテラー に乗ります
# 2022-08-17 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-17 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 49 のスケジュールと最大人気度スコア:
# 2022-08-18 09:32:00 に タワーオブテラー に乗ります
# 2022-08-18 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-18 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 50 のスケジュールと最大人気度スコア:
# 2022-08-19 09:32:00 に タワーオブテラー に乗ります
# 2022-08-19 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-19 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 51 のスケジュールと最大人気度スコア:
# 2022-08-20 09:32:00 に タワーオブテラー に乗ります
# 2022-08-20 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-20 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 52 のスケジュールと最大人気度スコア:
# 2022-08-21 09:32:00 に タワーオブテラー に乗ります
# 2022-08-21 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-21 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 53 のスケジュールと最大人気度スコア:
# 2022-08-22 09:32:00 に タワーオブテラー に乗ります
# 2022-08-22 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-22 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 54 のスケジュールと最大人気度スコア:
# 2022-08-23 09:32:00 に タワーオブテラー に乗ります
# 2022-08-23 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-23 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 55 のスケジュールと最大人気度スコア:
# 2022-08-24 09:32:00 に タワーオブテラー に乗ります
# 2022-08-24 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-24 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 56 のスケジュールと最大人気度スコア:
# 2022-08-25 09:32:00 に タワーオブテラー に乗ります
# 2022-08-25 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-25 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 57 のスケジュールと最大人気度スコア:
# 2022-08-26 09:32:00 に タワーオブテラー に乗ります
# 2022-08-26 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-26 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 58 のスケジュールと最大人気度スコア:
# 2022-08-27 09:32:00 に タワーオブテラー に乗ります
# 2022-08-27 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-27 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 59 のスケジュールと最大人気度スコア:
# 2022-08-28 09:32:00 に タワーオブテラー に乗ります
# 2022-08-28 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-28 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 60 のスケジュールと最大人気度スコア:
# 2022-08-29 09:32:00 に タワーオブテラー に乗ります
# 2022-08-29 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-29 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 61 のスケジュールと最大人気度スコア:
# 2022-08-30 09:32:00 に タワーオブテラー に乗ります
# 2022-08-30 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-30 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 62 のスケジュールと最大人気度スコア:
# 2022-08-31 09:32:00 に タワーオブテラー に乗ります
# 2022-08-31 10:09:00 に トイストーリーマニア に乗ります
# 2022-08-31 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 63 のスケジュールと最大人気度スコア:
# 2022-09-01 09:32:00 に タワーオブテラー に乗ります
# 2022-09-01 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-01 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 64 のスケジュールと最大人気度スコア:
# 2022-09-02 09:32:00 に タワーオブテラー に乗ります
# 2022-09-02 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-02 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 65 のスケジュールと最大人気度スコア:
# 2022-09-03 09:32:00 に タワーオブテラー に乗ります
# 2022-09-03 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-03 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 66 のスケジュールと最大人気度スコア:
# 2022-09-04 09:32:00 に タワーオブテラー に乗ります
# 2022-09-04 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-04 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 67 のスケジュールと最大人気度スコア:
# 2022-09-05 09:32:00 に タワーオブテラー に乗ります
# 2022-09-05 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-05 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 68 のスケジュールと最大人気度スコア:
# 2022-09-06 09:32:00 に タワーオブテラー に乗ります
# 2022-09-06 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-06 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 69 のスケジュールと最大人気度スコア:
# 2022-09-07 09:32:00 に タワーオブテラー に乗ります
# 2022-09-07 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-07 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 70 のスケジュールと最大人気度スコア:
# 2022-09-08 09:32:00 に タワーオブテラー に乗ります
# 2022-09-08 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-08 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 71 のスケジュールと最大人気度スコア:
# 2022-09-09 09:32:00 に タワーオブテラー に乗ります
# 2022-09-09 10:29:00 に トイストーリーマニア に乗ります
# 2022-09-09 10:34:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 72 のスケジュールと最大人気度スコア:
# 2022-09-10 09:32:00 に タワーオブテラー に乗ります
# 2022-09-10 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-10 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 73 のスケジュールと最大人気度スコア:
# 2022-09-11 09:32:00 に タワーオブテラー に乗ります
# 2022-09-11 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-11 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 74 のスケジュールと最大人気度スコア:
# 2022-09-12 09:32:00 に タワーオブテラー に乗ります
# 2022-09-12 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-12 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 75 のスケジュールと最大人気度スコア:
# 2022-09-13 09:32:00 に タワーオブテラー に乗ります
# 2022-09-13 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-13 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 76 のスケジュールと最大人気度スコア:
# 2022-09-14 09:32:00 に タワーオブテラー に乗ります
# 2022-09-14 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-14 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 77 のスケジュールと最大人気度スコア:
# 2022-09-15 09:32:00 に タワーオブテラー に乗ります
# 2022-09-15 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-15 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 78 のスケジュールと最大人気度スコア:
# 2022-09-16 09:32:00 に タワーオブテラー に乗ります
# 2022-09-16 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-16 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 79 のスケジュールと最大人気度スコア:
# 2022-09-17 09:32:00 に タワーオブテラー に乗ります
# 2022-09-17 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-17 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 80 のスケジュールと最大人気度スコア:
# 2022-09-18 09:32:00 に タワーオブテラー に乗ります
# 2022-09-18 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-18 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 81 のスケジュールと最大人気度スコア:
# 2022-09-19 09:32:00 に タワーオブテラー に乗ります
# 2022-09-19 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-19 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 82 のスケジュールと最大人気度スコア:
# 2022-09-20 09:32:00 に タワーオブテラー に乗ります
# 2022-09-20 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-20 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 83 のスケジュールと最大人気度スコア:
# 2022-09-21 09:32:00 に タワーオブテラー に乗ります
# 2022-09-21 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-21 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 84 のスケジュールと最大人気度スコア:
# 2022-09-22 09:32:00 に タワーオブテラー に乗ります
# 2022-09-22 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-22 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 85 のスケジュールと最大人気度スコア:
# 2022-09-23 09:32:00 に タワーオブテラー に乗ります
# 2022-09-23 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-23 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 86 のスケジュールと最大人気度スコア:
# 2022-09-24 09:32:00 に タワーオブテラー に乗ります
# 2022-09-24 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-24 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 87 のスケジュールと最大人気度スコア:
# 2022-09-25 09:32:00 に タワーオブテラー に乗ります
# 2022-09-25 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-25 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 88 のスケジュールと最大人気度スコア:
# 2022-09-26 09:32:00 に タワーオブテラー に乗ります
# 2022-09-26 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-26 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 89 のスケジュールと最大人気度スコア:
# 2022-09-27 09:32:00 に タワーオブテラー に乗ります
# 2022-09-27 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-27 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 90 のスケジュールと最大人気度スコア:
# 2022-09-28 09:32:00 に タワーオブテラー に乗ります
# 2022-09-28 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-28 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 91 のスケジュールと最大人気度スコア:
# 2022-09-29 09:52:00 に タワーオブテラー に乗ります
# 2022-09-29 10:29:00 に トイストーリーマニア に乗ります
# 2022-09-29 10:34:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 92 のスケジュールと最大人気度スコア:
# 2022-09-30 09:32:00 に タワーオブテラー に乗ります
# 2022-09-30 10:09:00 に トイストーリーマニア に乗ります
# 2022-09-30 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 93 のスケジュールと最大人気度スコア:
# 2022-10-01 09:47:00 に タワーオブテラー に乗ります
# 2022-10-01 10:24:00 に トイストーリーマニア に乗ります
# 2022-10-01 10:29:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 94 のスケジュールと最大人気度スコア:
# 2022-10-02 09:52:00 に タワーオブテラー に乗ります
# 2022-10-02 10:29:00 に トイストーリーマニア に乗ります
# 2022-10-02 10:34:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 95 のスケジュールと最大人気度スコア:
# 2022-10-03 09:32:00 に タワーオブテラー に乗ります
# 2022-10-03 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-03 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 96 のスケジュールと最大人気度スコア:
# 2022-10-04 09:32:00 に タワーオブテラー に乗ります
# 2022-10-04 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-04 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 97 のスケジュールと最大人気度スコア:
# 2022-10-05 09:32:00 に タワーオブテラー に乗ります
# 2022-10-05 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-05 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 98 のスケジュールと最大人気度スコア:
# 2022-10-06 09:32:00 に タワーオブテラー に乗ります
# 2022-10-06 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-06 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 99 のスケジュールと最大人気度スコア:
# 2022-10-07 09:32:00 に タワーオブテラー に乗ります
# 2022-10-07 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-07 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 100 のスケジュールと最大人気度スコア:
# 2022-10-08 09:32:00 に タワーオブテラー に乗ります
# 2022-10-08 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-08 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 101 のスケジュールと最大人気度スコア:
# 2022-10-09 09:57:00 に タワーオブテラー に乗ります
# 2022-10-09 10:34:00 に トイストーリーマニア に乗ります
# 2022-10-09 10:39:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 102 のスケジュールと最大人気度スコア:
# 2022-10-10 09:32:00 に タワーオブテラー に乗ります
# 2022-10-10 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-10 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 103 のスケジュールと最大人気度スコア:
# 2022-10-11 09:32:00 に タワーオブテラー に乗ります
# 2022-10-11 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-11 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 104 のスケジュールと最大人気度スコア:
# 2022-10-12 09:32:00 に タワーオブテラー に乗ります
# 2022-10-12 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-12 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 105 のスケジュールと最大人気度スコア:
# 2022-10-13 09:32:00 に タワーオブテラー に乗ります
# 2022-10-13 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-13 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 106 のスケジュールと最大人気度スコア:
# 2022-10-14 09:32:00 に タワーオブテラー に乗ります
# 2022-10-14 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-14 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 107 のスケジュールと最大人気度スコア:
# 2022-10-15 09:47:00 に タワーオブテラー に乗ります
# 2022-10-15 10:24:00 に トイストーリーマニア に乗ります
# 2022-10-15 10:29:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 108 のスケジュールと最大人気度スコア:
# 2022-10-16 09:32:00 に タワーオブテラー に乗ります
# 2022-10-16 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-16 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 109 のスケジュールと最大人気度スコア:
# 2022-10-17 09:32:00 に タワーオブテラー に乗ります
# 2022-10-17 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-17 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 110 のスケジュールと最大人気度スコア:
# 2022-10-18 09:32:00 に タワーオブテラー に乗ります
# 2022-10-18 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-18 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 111 のスケジュールと最大人気度スコア:
# 2022-10-19 09:32:00 に タワーオブテラー に乗ります
# 2022-10-19 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-19 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 112 のスケジュールと最大人気度スコア:
# 2022-10-20 09:32:00 に タワーオブテラー に乗ります
# 2022-10-20 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-20 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 113 のスケジュールと最大人気度スコア:
# 2022-10-21 09:32:00 に タワーオブテラー に乗ります
# 2022-10-21 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-21 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 114 のスケジュールと最大人気度スコア:
# 2022-10-22 09:32:00 に タワーオブテラー に乗ります
# 2022-10-22 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-22 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 115 のスケジュールと最大人気度スコア:
# 2022-10-23 09:32:00 に タワーオブテラー に乗ります
# 2022-10-23 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-23 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 116 のスケジュールと最大人気度スコア:
# 2022-10-24 09:32:00 に タワーオブテラー に乗ります
# 2022-10-24 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-24 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 117 のスケジュールと最大人気度スコア:
# 2022-10-25 09:32:00 に タワーオブテラー に乗ります
# 2022-10-25 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-25 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
# Batch 118 のスケジュールと最大人気度スコア:
# 2022-10-26 09:32:00 に タワーオブテラー に乗ります
# 2022-10-26 10:09:00 に トイストーリーマニア に乗ります
# 2022-10-26 10:14:00 に ソアリン に乗ります
# 最大人気度スコア: 208.0
# ----------------------------------------
