# %% [markdown]
# ### いつの時間帯にどのアトラクションを乗るのか

# %%
import pandas as pd
import os

attractions = {
    0: 'ソアリン',
    1: 'トイストーリーマニア',
    2: 'タワーオブテラー',
    3: 'センターオブジアース',
    4: 'インディージョーンズ',
    5: 'レイジングスピリッツ',
    6: 'マジックランプシアター',
    7: 'タートルトーク'
}

# CSVファイルを読み込む
df = pd.read_csv('./combined_reviews.csv')

# '最適プラン'と'タイムスケジュール'を取り出し、1次元配列に変換
optimal_plan = [eval(plan) for plan in df["最適プラン"]]
time_schedule = [eval(plan) for plan in df["タイムスケジュール"]]
#print(optimal_plan)
#print(time_schedule)

# 新しいデータフレームを作成（初期値を0で埋める）
result_df = pd.DataFrame(data=0, index=attractions.values(), columns=list(range(0, 721, 5)))
#display(result_df)

# '最適プラン'と'タイムスケジュール'を対応させて分別
c = 0
for y in optimal_plan:
    x = time_schedule[c]
    for i in range(len(y)):
        index = attractions.get(y[i])
        #print(f"Attraction: {index}, Time: {x[i]}")
        
        # .loc[]を使って結果を更新
        result_df.loc[index, x[i]] += 1
        #display(result_df)
    
    c += 1

result_df.to_csv(os.path.join('attraction_heatmap.csv'), index=True)

# %%
# 結果を表示
df_result = pd.read_csv('attraction_heatmap.csv', index_col=0)
display(df_result)
display(df_result.info())
display(df_result.shape)
# Out:
#                0  5  10  15  20  25   30  35  40   45  ...  675  680  685  \
# ソアリン         119  0   0   0   0   0   11   0   0   13  ...    0    0    0
# トイストーリーマニア   164  0   0   0   0   0   41   0   0   12  ...    0    0    0
# タワーオブテラー     402  0   0   0   0   0  116   0   0   69  ...    0    0    0
# センターオブジアース   379  0   0   0   0   0  193   0   0  141  ...    0    0    0
# インディージョーンズ   788  0   0   0   0   0  386   0   0  215  ...    0    0    0
# レイジングスピリッツ   675  0   0   0   0   0  472   0   0  157  ...    0    0    0
# マジックランプシアター  311  0   0   0   0   0  597   0   0  238  ...    0    0    0
# タートルトーク      242  0   0   0   0   0  276   0   0  165  ...    0    0    0
#
#              690  695  700  705  710  715  720
# ソアリン           0    0    0    0    0    0    0
# トイストーリーマニア     0    0    0    0    0    0    0
# タワーオブテラー       0    0    0    0    0    0    0
# センターオブジアース     0    0    0    0    0    0    0
# インディージョーンズ     0    0    0    0    0    0    0
# レイジングスピリッツ     0    0    0    0    0    0    0
# マジックランプシアター    0    0    0    0    0    0    0
# タートルトーク        0    0    0    0    0    0    0
#
# [8 rows x 145 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, ソアリン to タートルトーク
# Columns: 145 entries, 0 to 720
# dtypes: int64(145)
# memory usage: 9.1+ KB
# None
# (8, 145)
